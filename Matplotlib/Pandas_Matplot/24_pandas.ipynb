# %% [markdown]
# # Matplotlib e Pandas
#
# O Pandas é uma biblioteca que permite a manipulação de dados de forma simples e eficiente. Ela é construída sobre o NumPy e permite a manipulação de dados de forma simples e eficiente. Quanto a gráficos, o Pandas utiliza o Matplotlib como base para a geração de gráficos.

# %% [markdown]
# ## Base de dados utilizada
#
# Para este notebook, utilizaremos a base de dados do top 10 IBOV de maio a agosto de 2023. A base de dados foi obtida no site do Yahoo Finance. O IBOV é o índice da Bovespa, que é a bolsa de valores brasileira. O IBOV é composto pelas ações mais negociadas na bolsa de valores brasileira. Para compor o IBOV, é feito um cálculo de ponderação das ações, onde as ações mais negociadas possuem maior peso no índice. O IBOV é um índice que é utilizado para medir o desempenho médio das cotações das ações mais negociadas na bolsa de valores brasileira.
#
# Este material é didático e não tem como objetivo a recomendação de compra ou venda de ativos.

# %%
import numpy as np
import pandas as pd

ARQUIVO_TOP_10_IBOV = 'top_10_ibov_mai_ago_2023.csv'

df_top_10_ibov = pd.read_csv(ARQUIVO_TOP_10_IBOV)
df_top_10_ibov['Date'] = pd.to_datetime(df_top_10_ibov['Date'], format='%Y-%m-%d')
df_top_10_ibov = df_top_10_ibov.set_index('Date', drop=True)
df_top_10_ibov.head()
# Out:
#                 VALE3      ELET3      BBAS3      B3SA3  ABEV3      ITUB4  \
# Date
# 2023-01-02  87.478874  40.327332  31.615412  12.039818  14.19  23.893169
# 2023-01-03  87.322311  39.572250  31.026070  11.636853  14.17  23.395597
# 2023-01-04  87.478874  40.635326  31.425303  11.725308  14.25  23.463890
# 2023-01-05  88.946640  40.714806  32.860638  12.088961  14.29  24.195612
# 2023-01-06  90.355698  40.734676  33.316906  12.373984  14.32  24.615131
#
#                 BBDC4      WEGE3      PETR3      RENT3
# Date
# 2023-01-02  13.879215  37.771538  22.264847  50.636215
# 2023-01-03  13.190460  36.829731  21.950058  49.391312
# 2023-01-04  13.228148  37.077576  22.315893  49.974247
# 2023-01-05  13.802876  37.156883  23.039053  50.389210
# 2023-01-06  14.189168  37.702141  22.894421  51.347595

# %%
df_top_10_ibov.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 123 entries, 2023-01-02 to 2023-06-29
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   VALE3   123 non-null    float64
#  1   ELET3   123 non-null    float64
#  2   BBAS3   123 non-null    float64
#  3   B3SA3   123 non-null    float64
#  4   ABEV3   123 non-null    float64
#  5   ITUB4   123 non-null    float64
#  6   BBDC4   123 non-null    float64
#  7   WEGE3   123 non-null    float64
#  8   PETR3   123 non-null    float64
#  9   RENT3   123 non-null    float64
# dtypes: float64(10)
# memory usage: 10.6 KB

# %%
import matplotlib.pyplot as plt

plt.style.use('bmh')

df_top_10_ibov.plot(figsize=(10, 12), title='Top 10 IBOV', subplots=True, layout=(5, 2))
plt.show()

# %%
variacao_diaria = df_top_10_ibov.pct_change()
variacao_diaria.head()
# Out:
#                VALE3     ELET3     BBAS3     B3SA3     ABEV3     ITUB4  \
# Date
# 2023-01-02       NaN       NaN       NaN       NaN       NaN       NaN
# 2023-01-03 -0.001790 -0.018724 -0.018641 -0.033469 -0.001409 -0.020825
# 2023-01-04  0.001793  0.026864  0.012868  0.007601  0.005646  0.002919
# 2023-01-05  0.016779  0.001956  0.045675  0.031014  0.002807  0.031185
# 2023-01-06  0.015842  0.000488  0.013885  0.023577  0.002099  0.017339
#
#                BBDC4     WEGE3     PETR3     RENT3
# Date
# 2023-01-02       NaN       NaN       NaN       NaN
# 2023-01-03 -0.049625 -0.024934 -0.014138 -0.024585
# 2023-01-04  0.002857  0.006729  0.016667  0.011802
# 2023-01-05  0.043447  0.002139  0.032406  0.008304
# 2023-01-06  0.027986  0.014674 -0.006278  0.019020

# %%
from itertools import combinations

bancos = ['BBDC4', 'ITUB4', 'BBAS3']
pares_bancos = list(combinations(bancos, 2))
pares_bancos
# Out:
# [('BBDC4', 'ITUB4'), ('BBDC4', 'BBAS3'), ('ITUB4', 'BBAS3')]

# %%
fig, axs = plt.subplots(nrows=1, ncols=3, figsize=(16, 9))

for i, par in enumerate(pares_bancos):
    axs[i].scatter(par[0], par[1], data=df_top_10_ibov)
    axs[i].set_title(f'{par[0]} x {par[1]}')
    axs[i].set_xlabel(par[0])
    axs[i].set_ylabel(par[1])

fig.suptitle('Analisando correlação dos bancos', fontsize=16)

plt.show()

# %% [markdown]
# Podemos verificar que existe uma correlação positiva entre os pares de ações de bancos. Isso significa que quando uma ação sobe, a outra também sobe. Quando uma ação cai, a outra também cai. Isso é um indicativo de que existe uma correlação entre as ações de bancos. A correlação é uma medida estatística que indica a relação entre duas variáveis. A correlação pode ser positiva, negativa ou neutra. Quando a correlação é positiva, significa que as variáveis possuem uma relação direta. Quando uma variável aumenta, a outra também aumenta. Quando a correlação é negativa, significa que as variáveis possuem uma relação inversa. Quando uma variável aumenta, a outra diminui. Quando a correlação é neutra, significa que as variáveis não possuem relação entre si.
#
# Os valores da correlação variam entre -1 e 1. Quando a correlação é -1, significa que as variáveis possuem uma correlação negativa perfeita. Quando a correlação é 1, significa que as variáveis possuem uma correlação positiva perfeita. Quando a correlação é 0, significa que as variáveis não possuem correlação. Quanto mais próximo de 1 ou -1, mais forte é a correlação. Quanto mais próximo de 0, mais fraca é a correlação.
#
# O método `corr()` do Pandas calcula a correlação entre as variáveis de um DataFrame.

# %%
df_top_10_ibov.corr()
# Out:
#           VALE3     ELET3     BBAS3     B3SA3     ABEV3     ITUB4     BBDC4  \
# VALE3  1.000000  0.254017 -0.801388 -0.472413 -0.733513 -0.616604 -0.630104
# ELET3  0.254017  1.000000  0.072803  0.641147  0.089652  0.421773  0.476954
# BBAS3 -0.801388  0.072803  1.000000  0.665027  0.666072  0.858388  0.753427
# B3SA3 -0.472413  0.641147  0.665027  1.000000  0.576847  0.806739  0.932840
# ABEV3 -0.733513  0.089652  0.666072  0.576847  1.000000  0.573089  0.670614
# ITUB4 -0.616604  0.421773  0.858388  0.806739  0.573089  1.000000  0.883379
# BBDC4 -0.630104  0.476954  0.753427  0.932840  0.670614  0.883379  1.000000
# WEGE3 -0.114228 -0.748048 -0.213368 -0.575233 -0.033395 -0.450325 -0.443264
# PETR3 -0.649903  0.350004  0.924637  0.805945  0.614360  0.917005  0.856235
# RENT3 -0.699430  0.331517  0.895541  0.864826  0.582085  0.892079  0.888734
#
#           WEGE3     PETR3     RENT3
# VALE3 -0.114228 -0.649903 -0.699430
# ELET3 -0.748048  0.350004  0.331517
# BBAS3 -0.213368  0.924637  0.895541
# B3SA3 -0.575233  0.805945  0.864826
# ABEV3 -0.033395  0.614360  0.582085
# ITUB4 -0.450325  0.917005  0.892079
# BBDC4 -0.443264  0.856235  0.888734
# WEGE3  1.000000 -0.479820 -0.377449
# PETR3 -0.479820  1.000000  0.912472
# RENT3 -0.377449  0.912472  1.000000

# %% [markdown]
# Podemos aplicar um estilo de gradiente de cores para facilitar a visualização da correlação. No Pandas, há o método `style.background_gradient()`, que aplica um estilo de gradiente de cores no DataFrame. O parâmetro `cmap` recebe o nome do estilo de gradiente de cores. Neste caso, utilizaremos o estilo `coolwarm_r`, que é um estilo de gradiente de cores que vai do vermelho ao azul. O sufixo `_r` indica que o gradiente de cores será aplicado de forma reversa, ou seja, o gradiente original é de azul ao vermelho.
#
# Os mapas de cores são os disponíveis no Matplotlib. Para mais informações, acesse a [documentação](https://matplotlib.org/stable/tutorials/colors/colormaps.html).

# %%
df_top_10_ibov.corr().style.background_gradient(cmap="coolwarm_r")
# Out:
# <style type="text/css">
# #T_b81c5_row0_col0, #T_b81c5_row1_col1, #T_b81c5_row2_col2, #T_b81c5_row3_col3, #T_b81c5_row4_col4, #T_b81c5_row5_col5, #T_b81c5_row6_col6, #T_b81c5_row7_col7, #T_b81c5_row8_col8, #T_b81c5_row9_col9 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_b81c5_row0_col1 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_b81c5_row0_col2, #T_b81c5_row0_col4, #T_b81c5_row0_col5, #T_b81c5_row0_col6, #T_b81c5_row0_col8, #T_b81c5_row0_col9, #T_b81c5_row1_col7, #T_b81c5_row2_col0, #T_b81c5_row7_col1, #T_b81c5_row7_col3 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_b81c5_row0_col3 {
#   background-color: #cb3e38;
#   color: #f1f1f1;
# }
# #T_b81c5_row0_col7 {
#   background-color: #f5c0a7;
#   color: #000000;
# }
# #T_b81c5_row1_col0 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_b81c5_row1_col2 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_b81c5_row1_col3 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_b81c5_row1_col4 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_b81c5_row1_col5 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_b81c5_row1_col6 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_b81c5_row1_col8, #T_b81c5_row1_col9 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_b81c5_row2_col1 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_b81c5_row2_col3 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_b81c5_row2_col4 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_b81c5_row2_col5, #T_b81c5_row6_col8, #T_b81c5_row8_col6 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_b81c5_row2_col6 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_b81c5_row2_col7 {
#   background-color: #f7af91;
#   color: #000000;
# }
# #T_b81c5_row2_col8 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_b81c5_row2_col9 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_b81c5_row3_col0 {
#   background-color: #ea7b60;
#   color: #f1f1f1;
# }
# #T_b81c5_row3_col1 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_b81c5_row3_col2, #T_b81c5_row4_col2 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_b81c5_row3_col4, #T_b81c5_row4_col9 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_b81c5_row3_col5, #T_b81c5_row3_col8 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_b81c5_row3_col6, #T_b81c5_row6_col3, #T_b81c5_row8_col2 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_b81c5_row3_col7 {
#   background-color: #d65244;
#   color: #f1f1f1;
# }
# #T_b81c5_row3_col9, #T_b81c5_row5_col2 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_b81c5_row4_col0 {
#   background-color: #c12b30;
#   color: #f1f1f1;
# }
# #T_b81c5_row4_col1 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_b81c5_row4_col3 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_b81c5_row4_col5 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_b81c5_row4_col6 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_b81c5_row4_col7 {
#   background-color: #f1cdba;
#   color: #000000;
# }
# #T_b81c5_row4_col8 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_b81c5_row5_col0, #T_b81c5_row7_col5, #T_b81c5_row7_col8 {
#   background-color: #d75445;
#   color: #f1f1f1;
# }
# #T_b81c5_row5_col1 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_b81c5_row5_col3, #T_b81c5_row8_col3 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_b81c5_row5_col4 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_b81c5_row5_col6, #T_b81c5_row6_col5 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_b81c5_row5_col7 {
#   background-color: #e8765c;
#   color: #f1f1f1;
# }
# #T_b81c5_row5_col8 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_b81c5_row5_col9, #T_b81c5_row6_col9 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_b81c5_row6_col0 {
#   background-color: #d55042;
#   color: #f1f1f1;
# }
# #T_b81c5_row6_col1 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_b81c5_row6_col2 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_b81c5_row6_col4 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_b81c5_row6_col7 {
#   background-color: #e9785d;
#   color: #f1f1f1;
# }
# #T_b81c5_row7_col0 {
#   background-color: #f4c6af;
#   color: #000000;
# }
# #T_b81c5_row7_col2 {
#   background-color: #f7b599;
#   color: #000000;
# }
# #T_b81c5_row7_col4 {
#   background-color: #f1ccb8;
#   color: #000000;
# }
# #T_b81c5_row7_col6 {
#   background-color: #da5a49;
#   color: #f1f1f1;
# }
# #T_b81c5_row7_col9 {
#   background-color: #ec7f63;
#   color: #f1f1f1;
# }
# #T_b81c5_row8_col0 {
#   background-color: #d1493f;
#   color: #f1f1f1;
# }
# #T_b81c5_row8_col1 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_b81c5_row8_col4 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_b81c5_row8_col5, #T_b81c5_row8_col9, #T_b81c5_row9_col8 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_b81c5_row8_col7 {
#   background-color: #e46e56;
#   color: #f1f1f1;
# }
# #T_b81c5_row9_col0 {
#   background-color: #c83836;
#   color: #f1f1f1;
# }
# #T_b81c5_row9_col1 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_b81c5_row9_col2 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_b81c5_row9_col3 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_b81c5_row9_col4 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_b81c5_row9_col5, #T_b81c5_row9_col6 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_b81c5_row9_col7 {
#   background-color: #f08a6c;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_b81c5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b81c5_level0_col0" class="col_heading level0 col0" >VALE3</th>
#       <th id="T_b81c5_level0_col1" class="col_heading level0 col1" >ELET3</th>
#       <th id="T_b81c5_level0_col2" class="col_heading level0 col2" >BBAS3</th>
#       <th id="T_b81c5_level0_col3" class="col_heading level0 col3" >B3SA3</th>
#       <th id="T_b81c5_level0_col4" class="col_heading level0 col4" >ABEV3</th>
#       <th id="T_b81c5_level0_col5" class="col_heading level0 col5" >ITUB4</th>
#       <th id="T_b81c5_level0_col6" class="col_heading level0 col6" >BBDC4</th>
#       <th id="T_b81c5_level0_col7" class="col_heading level0 col7" >WEGE3</th>
#       <th id="T_b81c5_level0_col8" class="col_heading level0 col8" >PETR3</th>
#       <th id="T_b81c5_level0_col9" class="col_heading level0 col9" >RENT3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b81c5_level0_row0" class="row_heading level0 row0" >VALE3</th>
#       <td id="T_b81c5_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_b81c5_row0_col1" class="data row0 col1" >0.254017</td>
#       <td id="T_b81c5_row0_col2" class="data row0 col2" >-0.801388</td>
#       <td id="T_b81c5_row0_col3" class="data row0 col3" >-0.472413</td>
#       <td id="T_b81c5_row0_col4" class="data row0 col4" >-0.733513</td>
#       <td id="T_b81c5_row0_col5" class="data row0 col5" >-0.616604</td>
#       <td id="T_b81c5_row0_col6" class="data row0 col6" >-0.630104</td>
#       <td id="T_b81c5_row0_col7" class="data row0 col7" >-0.114228</td>
#       <td id="T_b81c5_row0_col8" class="data row0 col8" >-0.649903</td>
#       <td id="T_b81c5_row0_col9" class="data row0 col9" >-0.699430</td>
#     </tr>
#     <tr>
#       <th id="T_b81c5_level0_row1" class="row_heading level0 row1" >ELET3</th>
#       <td id="T_b81c5_row1_col0" class="data row1 col0" >0.254017</td>
#       <td id="T_b81c5_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_b81c5_row1_col2" class="data row1 col2" >0.072803</td>
#       <td id="T_b81c5_row1_col3" class="data row1 col3" >0.641147</td>
#       <td id="T_b81c5_row1_col4" class="data row1 col4" >0.089652</td>
#       <td id="T_b81c5_row1_col5" class="data row1 col5" >0.421773</td>
#       <td id="T_b81c5_row1_col6" class="data row1 col6" >0.476954</td>
#       <td id="T_b81c5_row1_col7" class="data row1 col7" >-0.748048</td>
#       <td id="T_b81c5_row1_col8" class="data row1 col8" >0.350004</td>
#       <td id="T_b81c5_row1_col9" class="data row1 col9" >0.331517</td>
#     </tr>
#     <tr>
#       <th id="T_b81c5_level0_row2" class="row_heading level0 row2" >BBAS3</th>
#       <td id="T_b81c5_row2_col0" class="data row2 col0" >-0.801388</td>
#       <td id="T_b81c5_row2_

# %%
df_top_10_ibov.corr().style.format(precision=2).background_gradient(cmap="coolwarm_r", vmin=-1, vmax=1)
# Out:
# <style type="text/css">
# #T_fbe48_row0_col0, #T_fbe48_row1_col1, #T_fbe48_row2_col2, #T_fbe48_row3_col3, #T_fbe48_row4_col4, #T_fbe48_row5_col5, #T_fbe48_row6_col6, #T_fbe48_row7_col7, #T_fbe48_row8_col8, #T_fbe48_row9_col9 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_fbe48_row0_col1, #T_fbe48_row1_col0 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_fbe48_row0_col2, #T_fbe48_row2_col0 {
#   background-color: #d65244;
#   color: #f1f1f1;
# }
# #T_fbe48_row0_col3, #T_fbe48_row3_col0 {
#   background-color: #f59f80;
#   color: #000000;
# }
# #T_fbe48_row0_col4, #T_fbe48_row4_col0 {
#   background-color: #e0654f;
#   color: #f1f1f1;
# }
# #T_fbe48_row0_col5, #T_fbe48_row5_col0 {
#   background-color: #ec8165;
#   color: #f1f1f1;
# }
# #T_fbe48_row0_col6, #T_fbe48_row6_col0 {
#   background-color: #eb7d62;
#   color: #f1f1f1;
# }
# #T_fbe48_row0_col7, #T_fbe48_row7_col0 {
#   background-color: #ead4c8;
#   color: #000000;
# }
# #T_fbe48_row0_col8, #T_fbe48_row8_col0 {
#   background-color: #e9785d;
#   color: #f1f1f1;
# }
# #T_fbe48_row0_col9, #T_fbe48_row9_col0 {
#   background-color: #e36c55;
#   color: #f1f1f1;
# }
# #T_fbe48_row1_col2, #T_fbe48_row2_col1 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_fbe48_row1_col3, #T_fbe48_row3_col1 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_fbe48_row1_col4, #T_fbe48_row4_col1 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_fbe48_row1_col5, #T_fbe48_row5_col1 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_fbe48_row1_col6, #T_fbe48_row6_col1 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_fbe48_row1_col7, #T_fbe48_row7_col1 {
#   background-color: #de614d;
#   color: #f1f1f1;
# }
# #T_fbe48_row1_col8, #T_fbe48_row8_col1 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_fbe48_row1_col9, #T_fbe48_row9_col1 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_fbe48_row2_col3, #T_fbe48_row2_col4, #T_fbe48_row3_col2, #T_fbe48_row4_col2, #T_fbe48_row4_col6, #T_fbe48_row6_col4 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_fbe48_row2_col5, #T_fbe48_row5_col2, #T_fbe48_row6_col8, #T_fbe48_row8_col6 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_fbe48_row2_col6, #T_fbe48_row6_col2 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_fbe48_row2_col7, #T_fbe48_row7_col2 {
#   background-color: #f2c9b4;
#   color: #000000;
# }
# #T_fbe48_row2_col8, #T_fbe48_row8_col2 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_fbe48_row2_col9, #T_fbe48_row5_col9, #T_fbe48_row9_col2, #T_fbe48_row9_col5 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_fbe48_row3_col4, #T_fbe48_row4_col3, #T_fbe48_row4_col5, #T_fbe48_row5_col4 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_fbe48_row3_col5, #T_fbe48_row3_col8, #T_fbe48_row5_col3, #T_fbe48_row8_col3 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_fbe48_row3_col6, #T_fbe48_row6_col3 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_fbe48_row3_col7, #T_fbe48_row7_col3 {
#   background-color: #f08a6c;
#   color: #f1f1f1;
# }
# #T_fbe48_row3_col9, #T_fbe48_row9_col3 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_fbe48_row4_col7, #T_fbe48_row7_col4 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_fbe48_row4_col8, #T_fbe48_row8_col4 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_fbe48_row4_col9, #T_fbe48_row9_col4 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_fbe48_row5_col6, #T_fbe48_row6_col5, #T_fbe48_row6_col9, #T_fbe48_row9_col6 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_fbe48_row5_col7, #T_fbe48_row7_col5 {
#   background-color: #f6a385;
#   color: #000000;
# }
# #T_fbe48_row5_col8, #T_fbe48_row8_col5 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_fbe48_row6_col7, #T_fbe48_row7_col6 {
#   background-color: #f6a586;
#   color: #000000;
# }
# #T_fbe48_row7_col8, #T_fbe48_row8_col7 {
#   background-color: #f59d7e;
#   color: #000000;
# }
# #T_fbe48_row7_col9, #T_fbe48_row9_col7 {
#   background-color: #f7b093;
#   color: #000000;
# }
# #T_fbe48_row8_col9, #T_fbe48_row9_col8 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_fbe48">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fbe48_level0_col0" class="col_heading level0 col0" >VALE3</th>
#       <th id="T_fbe48_level0_col1" class="col_heading level0 col1" >ELET3</th>
#       <th id="T_fbe48_level0_col2" class="col_heading level0 col2" >BBAS3</th>
#       <th id="T_fbe48_level0_col3" class="col_heading level0 col3" >B3SA3</th>
#       <th id="T_fbe48_level0_col4" class="col_heading level0 col4" >ABEV3</th>
#       <th id="T_fbe48_level0_col5" class="col_heading level0 col5" >ITUB4</th>
#       <th id="T_fbe48_level0_col6" class="col_heading level0 col6" >BBDC4</th>
#       <th id="T_fbe48_level0_col7" class="col_heading level0 col7" >WEGE3</th>
#       <th id="T_fbe48_level0_col8" class="col_heading level0 col8" >PETR3</th>
#       <th id="T_fbe48_level0_col9" class="col_heading level0 col9" >RENT3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fbe48_level0_row0" class="row_heading level0 row0" >VALE3</th>
#       <td id="T_fbe48_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_fbe48_row0_col1" class="data row0 col1" >0.25</td>
#       <td id="T_fbe48_row0_col2" class="data row0 col2" >-0.80</td>
#       <td id="T_fbe48_row0_col3" class="data row0 col3" >-0.47</td>
#       <td id="T_fbe48_row0_col4" class="data row0 col4" >-0.73</td>
#       <td id="T_fbe48_row0_col5" class="data row0 col5" >-0.62</td>
#       <td id="T_fbe48_row0_col6" class="data row0 col6" >-0.63</td>
#       <td id="T_fbe48_row0_col7" class="data row0 col7" >-0.11</td>
#       <td id="T_fbe48_row0_col8" class="data row0 col8" >-0.65</td>
#       <td id="T_fbe48_row0_col9" class="data row0 col9" >-0.70</td>
#     </tr>
#     <tr>
#       <th id="T_fbe48_level0_row1" class="row_heading level0 row1" >ELET3</th>
#       <td id="T_fbe48_row1_col0" class="data row1 col0" >0.25</td>
#       <td id="T_fbe48_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_fbe48_row1_col2" class="data row1 col2" >0.07</td>
#       <td id="T_fbe48_row1_col3" class="data row1 col3" >0.64</td>
#       <td id="T_fbe48_row1_col4" class="data row1 col4" >0.09</td>
#       <td id="T_fbe48_row1_col5" class="data row1 col5" >0.42</td>
#       <td id="T_fbe48_row1_col6" class="data row1 col6" >0.48</td>
#       <td id="T_fbe48_row1_col7" class="data row1 col7" >-0.75</td>
#       <td id="T_fbe48_row1_col8" class="data row1 col8" >0.35</td>
#       <td id="T_fbe48_row1_col9" class="data row1 col9" >0.33</td>
#     </tr>
#     <tr>
#       <th id="T_fbe48_level0_row2" class="row_heading level0 row2" >BBAS3</th>
#       <td id="T_fbe48_row2_col0" class="data row2 col0" >-0.80</td>
#       <td id="T_fbe48_row2_col1" class="data row2 col1" >0.07</td>
#       <td id="T_fbe48_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_fbe48_row2_col3" class="data row2 col3" >0.67</td>
#       <td id="T_fbe48_row2_col4" class="data row2 col4" >0.67</td>
#       <td id="T_fbe48_row2_col5" class="data row2 col5" >0.86</td>
#       <td id="T_fbe48_row2_col6" class="data row2 col6" >0.75</td>
#       <td id="T_fbe48_row2_col7" class="data row2 col7" >-0.21</td>
#       <td id="T_fbe48_row2_col8" class="data row2 col8" >0.92</td>
#       <td id="T_fbe48_row2_col9" class="data row2 col9" >0.90</td>
#     </tr>
#     <tr>
#       <th id="T_fbe48_level0_row3" class="row_heading level0 row3" >B3SA3</th>
#       <td id="T_fbe48_row3_col0" class="data row3 col0" >-0.47</td>
#       <td id="T_fbe48_row3_col1" class="data row3 col1" >0.64</td>
#       <td id="T_fbe48_row3_col2" class="data row3 col2" >0.67</td>
#       <td id="T_fbe48_row3_col3" class="data row3 col3" >1.00</td>
#       <td id="T_fbe48_row3_col4" class="data row3 col4" >0.58</td>
#       <td id="T_fbe48_row3_col5" class="data row3 col5" >0.81</td>
#       <td id="T_fbe48_row3_col6" class="data row3 col6" >0.93</td>
#       <td id="T_fbe48_row3_col7" class="data row3 col7" >-0.58</td>
#       <td id="T_fbe48_row3_col8" class="data row3 col8" >0.81</td>
#       <td id="T_fbe48_row3_col9" class="data row3 col9" >0.86</td>
#     </tr>
#     <tr>
#       <th id="T_fb

# %%
df_top_10_ibov[bancos].corr().style.format(precision=2).background_gradient(cmap="coolwarm_r", vmin=-1, vmax=1)
# Out:
# <style type="text/css">
# #T_456c4_row0_col0, #T_456c4_row1_col1, #T_456c4_row2_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_456c4_row0_col1, #T_456c4_row1_col0 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_456c4_row0_col2, #T_456c4_row2_col0 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_456c4_row1_col2, #T_456c4_row2_col1 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_456c4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_456c4_level0_col0" class="col_heading level0 col0" >BBDC4</th>
#       <th id="T_456c4_level0_col1" class="col_heading level0 col1" >ITUB4</th>
#       <th id="T_456c4_level0_col2" class="col_heading level0 col2" >BBAS3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_456c4_level0_row0" class="row_heading level0 row0" >BBDC4</th>
#       <td id="T_456c4_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_456c4_row0_col1" class="data row0 col1" >0.88</td>
#       <td id="T_456c4_row0_col2" class="data row0 col2" >0.75</td>
#     </tr>
#     <tr>
#       <th id="T_456c4_level0_row1" class="row_heading level0 row1" >ITUB4</th>
#       <td id="T_456c4_row1_col0" class="data row1 col0" >0.88</td>
#       <td id="T_456c4_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_456c4_row1_col2" class="data row1 col2" >0.86</td>
#     </tr>
#     <tr>
#       <th id="T_456c4_level0_row2" class="row_heading level0 row2" >BBAS3</th>
#       <td id="T_456c4_row2_col0" class="data row2 col0" >0.75</td>
#       <td id="T_456c4_row2_col1" class="data row2 col1" >0.86</td>
#       <td id="T_456c4_row2_col2" class="data row2 col2" >1.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_top_10_ibov.loc[:, df_top_10_ibov.columns.isin(bancos)].corr().style.format(precision=2).background_gradient(cmap="coolwarm_r", vmin=-1, vmax=1)
# Out:
# <style type="text/css">
# #T_00315_row0_col0, #T_00315_row1_col1, #T_00315_row2_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_00315_row0_col1, #T_00315_row1_col0 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_00315_row0_col2, #T_00315_row2_col0 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_00315_row1_col2, #T_00315_row2_col1 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_00315">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_00315_level0_col0" class="col_heading level0 col0" >BBAS3</th>
#       <th id="T_00315_level0_col1" class="col_heading level0 col1" >ITUB4</th>
#       <th id="T_00315_level0_col2" class="col_heading level0 col2" >BBDC4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_00315_level0_row0" class="row_heading level0 row0" >BBAS3</th>
#       <td id="T_00315_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_00315_row0_col1" class="data row0 col1" >0.86</td>
#       <td id="T_00315_row0_col2" class="data row0 col2" >0.75</td>
#     </tr>
#     <tr>
#       <th id="T_00315_level0_row1" class="row_heading level0 row1" >ITUB4</th>
#       <td id="T_00315_row1_col0" class="data row1 col0" >0.86</td>
#       <td id="T_00315_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_00315_row1_col2" class="data row1 col2" >0.88</td>
#     </tr>
#     <tr>
#       <th id="T_00315_level0_row2" class="row_heading level0 row2" >BBDC4</th>
#       <td id="T_00315_row2_col0" class="data row2 col0" >0.75</td>
#       <td id="T_00315_row2_col1" class="data row2 col1" >0.88</td>
#       <td id="T_00315_row2_col2" class="data row2 col2" >1.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_top_10_ibov.loc[:, ~df_top_10_ibov.columns.isin(bancos)].corr().style.format(precision=2).background_gradient(cmap="coolwarm_r", vmin=-1, vmax=1)
# Out:
# <style type="text/css">
# #T_ccb0d_row0_col0, #T_ccb0d_row1_col1, #T_ccb0d_row2_col2, #T_ccb0d_row3_col3, #T_ccb0d_row4_col4, #T_ccb0d_row5_col5, #T_ccb0d_row6_col6 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_ccb0d_row0_col1, #T_ccb0d_row1_col0 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_ccb0d_row0_col2, #T_ccb0d_row2_col0 {
#   background-color: #f59f80;
#   color: #000000;
# }
# #T_ccb0d_row0_col3, #T_ccb0d_row3_col0 {
#   background-color: #e0654f;
#   color: #f1f1f1;
# }
# #T_ccb0d_row0_col4, #T_ccb0d_row4_col0 {
#   background-color: #ead4c8;
#   color: #000000;
# }
# #T_ccb0d_row0_col5, #T_ccb0d_row5_col0 {
#   background-color: #e9785d;
#   color: #f1f1f1;
# }
# #T_ccb0d_row0_col6, #T_ccb0d_row6_col0 {
#   background-color: #e36c55;
#   color: #f1f1f1;
# }
# #T_ccb0d_row1_col2, #T_ccb0d_row2_col1 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_ccb0d_row1_col3, #T_ccb0d_row3_col1 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_ccb0d_row1_col4, #T_ccb0d_row4_col1 {
#   background-color: #de614d;
#   color: #f1f1f1;
# }
# #T_ccb0d_row1_col5, #T_ccb0d_row5_col1 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_ccb0d_row1_col6, #T_ccb0d_row6_col1 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_ccb0d_row2_col3, #T_ccb0d_row3_col2 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_ccb0d_row2_col4, #T_ccb0d_row4_col2 {
#   background-color: #f08a6c;
#   color: #f1f1f1;
# }
# #T_ccb0d_row2_col5, #T_ccb0d_row5_col2 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_ccb0d_row2_col6, #T_ccb0d_row6_col2 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_ccb0d_row3_col4, #T_ccb0d_row4_col3 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_ccb0d_row3_col5, #T_ccb0d_row5_col3 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_ccb0d_row3_col6, #T_ccb0d_row6_col3 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_ccb0d_row4_col5, #T_ccb0d_row5_col4 {
#   background-color: #f59d7e;
#   color: #000000;
# }
# #T_ccb0d_row4_col6, #T_ccb0d_row6_col4 {
#   background-color: #f7b093;
#   color: #000000;
# }
# #T_ccb0d_row5_col6, #T_ccb0d_row6_col5 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_ccb0d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ccb0d_level0_col0" class="col_heading level0 col0" >VALE3</th>
#       <th id="T_ccb0d_level0_col1" class="col_heading level0 col1" >ELET3</th>
#       <th id="T_ccb0d_level0_col2" class="col_heading level0 col2" >B3SA3</th>
#       <th id="T_ccb0d_level0_col3" class="col_heading level0 col3" >ABEV3</th>
#       <th id="T_ccb0d_level0_col4" class="col_heading level0 col4" >WEGE3</th>
#       <th id="T_ccb0d_level0_col5" class="col_heading level0 col5" >PETR3</th>
#       <th id="T_ccb0d_level0_col6" class="col_heading level0 col6" >RENT3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ccb0d_level0_row0" class="row_heading level0 row0" >VALE3</th>
#       <td id="T_ccb0d_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_ccb0d_row0_col1" class="data row0 col1" >0.25</td>
#       <td id="T_ccb0d_row0_col2" class="data row0 col2" >-0.47</td>
#       <td id="T_ccb0d_row0_col3" class="data row0 col3" >-0.73</td>
#       <td id="T_ccb0d_row0_col4" class="data row0 col4" >-0.11</td>
#       <td id="T_ccb0d_row0_col5" class="data row0 col5" >-0.65</td>
#       <td id="T_ccb0d_row0_col6" class="data row0 col6" >-0.70</td>
#     </tr>
#     <tr>
#       <th id="T_ccb0d_level0_row1" class="row_heading level0 row1" >ELET3</th>
#       <td id="T_ccb0d_row1_col0" class="data row1 col0" >0.25</td>
#       <td id="T_ccb0d_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_ccb0d_row1_col2" class="data row1 col2" >0.64</td>
#       <td id="T_ccb0d_row1_col3" class="data row1 col3" >0.09</td>
#       <td id="T_ccb0d_row1_col4" class="data row1 col4" >-0.75</td>
#       <td id="T_ccb0d_row1_col5" class="data row1 col5" >0.35</td>
#       <td id="T_ccb0d_row1_col6" class="data row1 col6" >0.33</td>
#     </tr>
#     <tr>
#       <th id="T_ccb0d_level0_row2" class="row_heading level0 row2" >B3SA3</th>
#       <td id="T_ccb0d_row2_col0" class="data row2 col0" >-0.47</td>
#       <td id="T_ccb0d_row2_col1" class="data row2 col1" >0.64</td>
#       <td id="T_ccb0d_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_ccb0d_row2_col3" class="data row2 col3" >0.58</td>
#       <td id="T_ccb0d_row2_col4" class="data row2 col4" >-0.58</td>
#       <td id="T_ccb0d_row2_col5" class="data row2 col5" >0.81</td>
#       <td id="T_ccb0d_row2_col6" class="data row2 col6" >0.86</td>
#     </tr>
#     <tr>
#       <th id="T_ccb0d_level0_row3" class="row_heading level0 row3" >ABEV3</th>
#       <td id="T_ccb0d_row3_col0" class="data row3 col0" >-0.73</td>
#       <td id="T_ccb0d_row3_col1" class="data row3 col1" >0.09</td>
#       <td id="T_ccb0d_row3_col2" class="data row3 col2" >0.58</td>
#       <td id="T_ccb0d_row3_col3" class="data row3 col3" >1.00</td>
#       <td id="T_ccb0d_row3_col4" class="data row3 col4" >-0.03</td>
#       <td id="T_ccb0d_row3_col5" class="data row3 col5" >0.61</td>
#       <td id="T_ccb0d_row3_col6" class="data row3 col6" >0.58</td>
#     </tr>
#     <tr>
#       <th id="T_ccb0d_level0_row4" class="row_heading level0 row4" >WEGE3</th>
#       <td id="T_ccb0d_row4_col0" class="data row4 col0" >-0.11</td>
#       <td id="T_ccb0d_row4_col1" class="data row4 col1" >-0.75</td>
#       <td id="T_ccb0d_row4_col2" class="data row4 col2" >-0.58</td>
#       <td id="T_ccb0d_row4_col3" class="data row4 col3" >-0.03</td>
#       <td id="T_ccb0d_row4_col4" class="data row4 col4" >1.00</td>
#       <td id="T_ccb0d_row4_col5" class="data row4 col5" >-0.48</td>
#       <td id="T_ccb0d_row4_col6" class="data row4 col6" >-0.38</td>
#     </tr>
#     <tr>
#       <th id="T_ccb0d_level0_row5" class="row_heading level0 row5" >PETR3</th>
#       <td id="T_ccb0d_row5_col0" class="data row5 col0" >-0.65</td>
#       <td id="T_ccb0d_row5_col1" class="data row5 col1" >0.35</td>
#       <td id="T_ccb0d_row5_col2" class="data row5 col2" >0.81</td>
#       <td id="T_ccb0d_row5_col3" class="data row5 col3" >0.61</td>
#       <td id="T_ccb0d_row5_col4" class="data row5 col4" >-0.48</td>
#       <td id="T_ccb0d_row5_col5" class="data row5 col5" >1.00</td>
#       <td id="T_ccb0d_row5_col6" class="data row5 col6" >0.91</td>
#     </tr>
#     <tr>
#       <th id="T_ccb0d_level0_row6" class="row_heading level0 row6" >RENT3</th>
#       <td id="T_ccb0d_row6_col0" class="data row6 col0" >-0.70</td>
#       <td id="T_ccb0d_row6_col1" class="data row6 col1" >0.33</td>
#       <td id="T_ccb0d_row6_col2" class="data row6 col2" >0.86</td>
#       <td id="T_ccb0d_row6_col3" class="data row6 col3" >0.58</td>
#       <td id="T_ccb0d_row6_col4" class="data row6 col4" >-0.38</td>
#       <td id="T_ccb0d_row6_col5" class="data row6 col5" >0.91</td>
#       <td id="T_ccb0d_row6_col6" class="data row6 col6" >1.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
from pandas.plotting import scatter_matrix

scatter_matrix(df_top_10_ibov, figsize=(12, 12));

# %%
df_top_10_ibov["VALE3"].value_counts(bins=10).sort_index()
# Out:
# (63.777, 67.018]    16
# (67.018, 70.227]    26
# (70.227, 73.435]     5
# (73.435, 76.644]     2
# (76.644, 79.852]    12
# (79.852, 83.06]     12
# (83.06, 86.269]     17
# (86.269, 89.477]    14
# (89.477, 92.686]    14
# (92.686, 95.894]     5
# Name: count, dtype: int64

# %%
df_top_10_ibov["VALE3"].value_counts(bins=5).sort_index()
# Out:
# (63.777, 70.227]    42
# (70.227, 76.644]     7
# (76.644, 83.06]     24
# (83.06, 89.477]     31
# (89.477, 95.894]    19
# Name: count, dtype: int64

# %%
scatter_matrix(df_top_10_ibov, figsize=(12, 12), hist_kwds={"bins": 5, "edgecolor": "black"});

# %%
scatter_matrix(df_top_10_ibov, figsize=(12, 12), hist_kwds={"bins": 10, "edgecolor": "black"});
