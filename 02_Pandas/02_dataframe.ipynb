# %%
dados = {
    "Nome" : [
        "Molodoy",
        "Fallen",
        "KS"
        ], 
    "Idade" : [22, 35, 26],
    "Profissão" : ["AWP","Professor","AK"]
}

# %%
import pandas as pd

df = pd.DataFrame(dados)

# %%
df
# Out:
#       Nome  Idade  Profissão
# 0  Molodoy     22        AWP
# 1   Fallen     35  Professor
# 2       KS     26         AK

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df["Nome"]
# Out:
# 0    Molodoy
# 1     Fallen
# 2         KS
# Name: Nome, dtype: object

# %%
type(df["Nome"])
# Out:
# pandas.core.series.Series

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Nome       3 non-null      object
#  1   Idade      3 non-null      int64
#  2   Profissão  3 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 204.0+ bytes

# %%
df.dtypes
# Out:
# Nome         object
# Idade         int64
# Profissão    object
# dtype: object

# %%
df["Idade"].mean()
# Out:
# np.float64(27.666666666666668)

# %%
df["Idade"].max()
# Out:
# 35

# %%
df.describe()
# Out:
#            Idade
# count   3.000000
# mean   27.666667
# std     6.658328
# min    22.000000
# 25%    24.000000
# 50%    26.000000
# 75%    30.500000
# max    35.000000

# %%
df.describe(exclude="number")
# Out:
#            Nome Profissão
# count         3         3
# unique        3         3
# top     Molodoy       AWP
# freq          1         1
