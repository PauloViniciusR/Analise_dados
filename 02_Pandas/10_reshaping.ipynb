# %%
import pandas as pd

# %%
df = pd.read_excel("dados/reshaping.xlsx")
df
# Out:
#    Estudante Categoria  Semana          Tópico  Nota
# 0      Maria    Testes       1       1. Python   100
# 1      Maria   Projeto       1       1. Python   100
# 2      Maria    Testes       1       2. GitHub    70
# 3      Maria   Projeto       1       2. GitHub    70
# 4      Maria    Testes       2   3. Matplotlib    80
# 5      Maria   Projeto       2   3. Matplotlib    70
# 6      Maria    Testes       2          4. SQL    80
# 7      Maria   Projeto       2          4. SQL    70
# 8      Maria    Testes       3        5. NumPy    60
# 9      Maria   Projeto       3        5. NumPy    60
# 10     Maria    Testes       3          6. POO    90
# 11     Maria   Projeto       3          6. POO    80
# 12     Maria    Testes       4       7. Pandas    70
# 13     Maria   Projeto       4       7. Pandas    70
# 14     Maria    Testes       4  8. Estatística    80
# 15     Maria   Projeto       4  8. Estatística    80
# 16      João    Testes       1       1. Python   100
# ...

# %%
df_pivot = df.pivot(
    index=["Estudante"],
    columns=["Categoria", "Semana", "Tópico"],
    values="Nota"
)

df_pivot
# Out:
# Categoria    Testes   Projeto    Testes   Projeto        Testes       Projeto  \
# Semana            1         1         1         1             2             2
# Tópico    1. Python 1. Python 2. GitHub 2. GitHub 3. Matplotlib 3. Matplotlib
# Estudante
# João            100        80        90        90            60            70
# Maria           100       100        70        70            80            70
#
# Categoria Testes Projeto   Testes  Projeto Testes Projeto    Testes   Projeto  \
# Semana         2       2        3        3      3       3         4         4
# Tópico    4. SQL  4. SQL 5. NumPy 5. NumPy 6. POO  6. POO 7. Pandas 7. Pandas
# Estudante
# João          70      80       80       90     70      80        70       100
# Maria         80      70       60       60     90      80        70        70
#
# Categoria         Testes        Projeto
# Semana                 4              4
# Tópico    8. Estatística 8. Estatística
# Estudante
# ...

# %%
df_pivot.index
# Out:
# Index(['João', 'Maria'], dtype='object', name='Estudante')

# %%
df_pivot.columns
# Out:
# MultiIndex([( 'Testes', 1,      '1. Python'),
#             ('Projeto', 1,      '1. Python'),
#             ( 'Testes', 1,      '2. GitHub'),
#             ('Projeto', 1,      '2. GitHub'),
#             ( 'Testes', 2,  '3. Matplotlib'),
#             ('Projeto', 2,  '3. Matplotlib'),
#             ( 'Testes', 2,         '4. SQL'),
#             ('Projeto', 2,         '4. SQL'),
#             ( 'Testes', 3,       '5. NumPy'),
#             ('Projeto', 3,       '5. NumPy'),
#             ( 'Testes', 3,         '6. POO'),
#             ('Projeto', 3,         '6. POO'),
#             ( 'Testes', 4,      '7. Pandas'),
#             ('Projeto', 4,      '7. Pandas'),
#             ( 'Testes', 4, '8. Estatística'),
#             ('Projeto', 4, '8. Estatística')],
#            names=['Categoria', 'Semana', 'Tópico'])

# %%
df_pivot.stack(level=0) #Stack pegar infos que estão em colunas e jogar para as linhas
# Out:
# /tmp/ipykernel_305765/10025394.py:1: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   df_pivot.stack(level=0)
# Semana                      1                       2               3         \
# Tópico              1. Python 2. GitHub 3. Matplotlib 4. SQL 5. NumPy 6. POO
# Estudante Categoria
# João      Projeto          80        90            70     80       90     80
#           Testes          100        90            60     70       80     70
# Maria     Projeto         100        70            70     70       60     80
#           Testes          100        70            80     80       60     90
#
# Semana                      4
# Tópico              7. Pandas 8. Estatística
# Estudante Categoria
# João      Projeto         100             90
# ...

# %%
df_pivot.stack(level=0).index
# Out:
# /tmp/ipykernel_305765/3153054886.py:1: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   df_pivot.stack(level=0).index
# MultiIndex([( 'João', 'Projeto'),
#             ( 'João',  'Testes'),
#             ('Maria', 'Projeto'),
#             ('Maria',  'Testes')],
#            names=['Estudante', 'Categoria'])

# %%
df_pivot.stack(level=0).columns
# Out:
# /tmp/ipykernel_305765/3251203482.py:1: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   df_pivot.stack(level=0).columns
# MultiIndex([(1,      '1. Python'),
#             (1,      '2. GitHub'),
#             (2,  '3. Matplotlib'),
#             (2,         '4. SQL'),
#             (3,       '5. NumPy'),
#             (3,         '6. POO'),
#             (4,      '7. Pandas'),
#             (4, '8. Estatística')],
#            names=['Semana', 'Tópico'])

# %%
df_pivot.stack(level=0).unstack(level=0)
# Out:
# /tmp/ipykernel_305765/1451058433.py:1: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   df_pivot.stack(level=0).unstack(level=0)
# Semana            1                                   2                     \
# Tópico    1. Python       2. GitHub       3. Matplotlib       4. SQL
# Estudante      João Maria      João Maria          João Maria   João Maria
# Categoria
# Projeto          80   100        90    70            70    70     80    70
# Testes          100   100        90    70            60    80     70    80
#
# Semana           3                            4
# Tópico    5. NumPy       6. POO       7. Pandas       8. Estatística
# Estudante     João Maria   João Maria      João Maria           João Maria
# Categoria
# ...
